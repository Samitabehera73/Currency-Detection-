# %%
# !pip install tensorflow opencv-python matplotlib numpy

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D

# %%
IMG_SIZE = 128
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

valid_datagen = ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    r"C:\Users\SAMITA\currency classification\dataset\train",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

valid_generator = valid_datagen.flow_from_directory(
    r"C:\Users\SAMITA\currency classification\dataset\valid",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

print(train_generator.class_indices)
# Out:
# Found 116 images belonging to 6 classes.
# Found 36 images belonging to 6 classes.
# {'10': 0, '100': 1, '20': 2, '200': 3, '50': 4, '500': 5}

# %%
num_classes = len(train_generator.class_indices)

base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(128,128,3)
)

base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_128            │ (None, 4, 4, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ...

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=20
)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.2241 - loss: 2.2393 - val_accuracy: 0.3333 - val_loss: 1.8610
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4828 - loss: 1.3369 - val_accuracy: 0.3056 - val_loss: 1.6554
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5690 - loss: 1.1819 - val_accuracy: 0.4444 - val_loss: 1.2976
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6379 - loss: 0.9556 - val_accuracy: 0.4722 - val_loss: 1.2704
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7672 - loss: 0.7436 - val_accuracy: 0.6111 - val_loss: 1.0554
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7241 - loss: 0.7205 - val_accuracy: 0.4722 - val_loss: 1.1571
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.8362 - loss: 0.5556 - val_accuracy: 0.5833 - val_loss: 0.9975
# Epoch 8/20
# ...

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train","Validation"])

plt.show()

# %%
model.save("currency_mobilenet.keras")

# %%
import cv2
import numpy as np

model = load_model("currency_mobilenet.keras")

classes = sorted(
    list(train_generator.class_indices.keys())
)

img = cv2.imread(
    r"C:\Users\SAMITA\currency classification\dataset\valid\500\1.jpg"
)

img = cv2.resize(img,(128,128))
img = img.astype("float32")/255.0
img = np.expand_dims(img, axis=0)

prediction = model.predict(img, verbose=0)

class_id = np.argmax(prediction)

print("Detected Currency: ₹" + classes[class_id])
# Out:
# Detected Currency: ₹500

# %%
import os
import cv2
import numpy as np

classes = sorted(
    list(train_generator.class_indices.keys())
)

base = r"C:\Users\SAMITA\currency classification\dataset\valid"

for cls in classes:

    image_path = os.path.join(base, cls, "1.jpg")

    img = cv2.imread(image_path)

    img = cv2.resize(img,(128,128))
    img = img.astype("float32")/255.0
    img = np.expand_dims(img, axis=0)

    prediction = model.predict(img, verbose=0)

    predicted = classes[np.argmax(prediction)]

    print(f"Actual: ₹{cls} --> Predicted: ₹{predicted}")
# Out:
# Actual: ₹10 --> Predicted: ₹10
# Actual: ₹100 --> Predicted: ₹100
# Actual: ₹20 --> Predicted: ₹50
# Actual: ₹200 --> Predicted: ₹500
# Actual: ₹50 --> Predicted: ₹20
# Actual: ₹500 --> Predicted: ₹500

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

model = load_model("currency_mobilenet.keras")

classes = [
    "10",
    "100",
    "20",
    "200",
    "50",
    "500"
]

cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()

    if not ret:
        break

    h, w, _ = frame.shape

    x1 = w//4
    y1 = h//4
    x2 = 3*w//4
    y2 = 3*h//4

    cv2.rectangle(
        frame,
        (x1,y1),
        (x2,y2),
        (0,255,0),
        2
    )

    roi = frame[y1:y2, x1:x2]

    img = cv2.resize(roi,(128,128))
    img = img.astype("float32")/255.0
    img = np.expand_dims(img, axis=0)

    prediction = model.predict(img, verbose=0)

    class_id = np.argmax(prediction)

    confidence = np.max(prediction)

    text = (
        f"Rs.{classes[class_id]} "
        f"({confidence*100:.1f}%)"
    )

    cv2.putText(
        frame,
        text,
        (20,40),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0,255,0),
        2
    )

    cv2.imshow(
        "Currency Recognition",
        frame
    )

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
